# %%
import matplotlib.pyplot as plt
import numpy as np 
# %matplotlib inline

# %%
x = np.arange(1,12)
y = np.arange(13,24)

# %%
a = np.arange(50,60)
b = np.arange(60,70)

# %%
plt.scatter(x,y,c='r')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
# Out:
# Text(0.5, 1.0, 'Graph in 2D')

# %%
y = x*x

# %%
plt.plot(x,y,'g*--', linestyle = 'dashed', linewidth= 2, markersize = 15)
# Out:
# C:\Users\Vipinjot Singh\AppData\Local\Temp\ipykernel_9364\1563694348.py:1: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "g*--" (-> linestyle='--'). The keyword argument will take precedence.
#   plt.plot(x,y,'g*--', linestyle = 'dashed', linewidth= 2, markersize = 15)

# %%
plt.plot(x,y, 'yo--')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g--')
plt.subplot(2,2,3)
plt.plot(x,y,'bo')
